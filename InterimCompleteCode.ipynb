# %% [markdown]
# ## Kaggle

# %% [markdown]
# **Import**

# %%
# Import libraries
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.regression.linear_model import OLS
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from sklearn.linear_model import LinearRegression, LogisticRegression, LogisticRegressionCV, Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_predict
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from scipy import stats

# %%
# Import datasets
X_train = pd.read_csv('../Datasets/train_X.csv')
y_train = pd.read_csv('../Datasets/train_y.csv')
X_test = pd.read_csv('../Datasets/public_private_X.csv')

# %%
# Import datasets again as a copy
X_train_copy = pd.read_csv('../Datasets/train_X.csv')
y_train_copy = pd.read_csv('../Datasets/train_y.csv')
X_test_copy = pd.read_csv('../Datasets/public_private_X.csv')

# %% [markdown]
# **EDA**

# %%
# Examine the training data
display(X_train.head(2))
print(X_train.columns)
print(X_train.shape)
display(y_train.head(2))
print(y_train.shape)
# Out:
#    ID  DIVISION_NUMBER  PRODUCT_NUMBER PURCHASE_ORDER_DUE_DATE  \
# 0   0              101            3960              2014-07-31
# 1   2              101            5479              2014-09-02
#
#    COMPANY_VENDOR_NUMBER  SHIP_FROM_VENDOR  ORDER_DATE  ORDER_DAY_OF_WEEK  \
# 0                   1295              1371  2014-07-26                  0
# 1                   1295              1371  2014-08-20                  5
#
#    PRODUCT_CLASSIFICATION  PURCHASE_ORDER_TYPE  ...  \
# 0                      36                    0  ...
# 1                      36                    0  ...
#
#    GIVEN_TIME_TO_LEAD_TIME_RATIO DUE_DATE_WEEKDAY  PRODUCT_MARKET  \
# 0                           0.71                6            5327
# 1                           0.65                1            6135
#
#    RESERVABLE_INDICATOR  PRODUCT_STATUS  AVERAGE_DAILY_DEMAND_CASES  \
# 0                     Y               0                        1.48
# 1                     Y               0                        8.49
#
#    AVERAGE_VENDOR_ORDER_CYCLE_DAYS  AVERAGE_ORDER_CYCLE_DAYS  \
# 0                              7.0                  7.020016
# 1                              7.0                  7.000000
#
#    AVERAGE_ORDER_CYCLE_CASES  LEAD_TIME_TO_DISTANCE_RATIO
# 0                   9.313729                        0.021
# 1                  52.623575                        0.059
#
# [2 rows x 28 columns]
# Index(['ID', 'DIVISION_NUMBER', 'PRODUCT_NUMBER', 'PURCHASE_ORDER_DUE_DATE',
#        'COMPANY_VENDOR_NUMBER', 'SHIP_FROM_VENDOR', 'ORDER_DATE',
#        'ORDER_DAY_OF_WEEK', 'PRODUCT_CLASSIFICATION', 'PURCHASE_ORDER_TYPE',
#        'DISTANCE_IN_MILES', 'DIVISION_CODE', 'PURCHASE_FROM_VENDOR',
#        'AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET', 'ORDER_QUANTITY_DEVIATION',
#        'TRANSIT_LEAD_TIME', 'PURCHASING_LEAD_TIME',
#        'DAYS_BETWEEN_ORDER_AND_DUE_DATE', 'GIVEN_TIME_TO_LEAD_TIME_RATIO',
#        'DUE_DATE_WEEKDAY', 'PRODUCT_MARKET', 'RESERVABLE_INDICATOR',
#        'PRODUCT_STATUS', 'AVERAGE_DAILY_DEMAND_CASES',
#        'AVERAGE_VENDOR_ORDER_CYCLE_DAYS', 'AVERAGE_ORDER_CYCLE_DAYS',
#        'AVERAGE_ORDER_CYCLE_CASES', 'LEAD_TIME_TO_DISTANCE_RATIO'],
#       dtype='object')
# (20413, 28)
#    ID  ON_TIME_AND_COMPLETE
# 0   0                     1
# 1   2                     0
# (20413, 2)

# %%
# Examine the testing data
display(X_test.head(2))
print(X_test.shape)
# Out:
#    ID  DIVISION_NUMBER  PRODUCT_NUMBER PURCHASE_ORDER_DUE_DATE  \
# 0  11              102            3485              2014-10-20
# 1  19              100            5380              2014-10-28
#
#    COMPANY_VENDOR_NUMBER  SHIP_FROM_VENDOR  ORDER_DATE  ORDER_DAY_OF_WEEK  \
# 0                   1295               853  2014-10-18                  0
# 1                     44                45  2014-10-22                  5
#
#    PRODUCT_CLASSIFICATION  PURCHASE_ORDER_TYPE  ...  \
# 0                      36                    1  ...
# 1                      21                    1  ...
#
#    GIVEN_TIME_TO_LEAD_TIME_RATIO DUE_DATE_WEEKDAY  PRODUCT_MARKET  \
# 0                            1.0                3            5780
# 1                            1.0                1            2414
#
#    RESERVABLE_INDICATOR  PRODUCT_STATUS  AVERAGE_DAILY_DEMAND_CASES  \
# 0                     Y               0                        12.8
# 1                     Y               0                         1.6
#
#    AVERAGE_VENDOR_ORDER_CYCLE_DAYS  AVERAGE_ORDER_CYCLE_DAYS  \
# 0                            7.000                  7.000000
# 1                           18.105                 18.105882
#
#    AVERAGE_ORDER_CYCLE_CASES  LEAD_TIME_TO_DISTANCE_RATIO
# 0                  86.944667                        0.046
# 1                  21.264765                        0.007
#
# [2 rows x 28 columns]
# (10247, 28)

# %%
# Print the correlation matrix
X_train.select_dtypes(include = ['int64', 'float64']).corr()
# Out:
#                                              ID  DIVISION_NUMBER  \
# ID                                     1.000000         0.001493
# DIVISION_NUMBER                        0.001493         1.000000
# PRODUCT_NUMBER                         0.001944        -0.018820
# COMPANY_VENDOR_NUMBER                  0.005070        -0.130536
# SHIP_FROM_VENDOR                      -0.001690        -0.012856
# ORDER_DAY_OF_WEEK                      0.000034         0.028395
# PRODUCT_CLASSIFICATION                 0.003754        -0.061128
# PURCHASE_ORDER_TYPE                   -0.008048        -0.136128
# DISTANCE_IN_MILES                      0.009530         0.028613
# PURCHASE_FROM_VENDOR                  -0.004420        -0.092678
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET -0.006310        -0.008137
# ORDER_QUANTITY_DEVIATION               0.005768         0.007911
# TRANSIT_LEAD_TIME                     -0.008537        -0.163292
# PURCHASING_LEAD_TIME                  -0.007810        -0.040559
# DAYS_BETWEEN_ORDER_AND_DUE_DATE       -0.003961        -0.066182
# GIVEN_TIME_TO_LEAD_TIME_RATIO          0.007843        -0.037448
# DUE_DATE_WEEKDAY                       0.004247         0.009276
# PRODUCT_MARKET                        -0.002889         0.014589
# PRODUCT_STATUS                              NaN              NaN
# AVERAGE_DAILY_DEMAND_CASES            -0.006886        -0.059713
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS        0.004537         0.084351
# AVERAGE_ORDER_CYCLE_DAYS              -0.006044         0.082815
# AVERAGE_ORDER_CYCLE_CASES             -0.001973         0.015762
# LEAD_TIME_TO_DISTANCE_RATIO            0.002131         0.119514
#
#                                        PRODUCT_NUMBER  COMPANY_VENDOR_NUMBER  \
# ID                                           0.001944               0.005070
# DIVISION_NUMBER                             -0.018820              -0.130536
# PRODUCT_NUMBER                               1.000000               0.017296
# COMPANY_VENDOR_NUMBER                        0.017296               1.000000
# SHIP_FROM_VENDOR                            -0.005264               0.730550
# ORDER_DAY_OF_WEEK                           -0.017917              -0.072054
# PRODUCT_CLASSIFICATION                       0.002122               0.328738
# PURCHASE_ORDER_TYPE                         -0.012811               0.093357
# DISTANCE_IN_MILES                            0.043117              -0.086397
# PURCHASE_FROM_VENDOR                         0.010871               0.390104
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET        0.002290              -0.028492
# ORDER_QUANTITY_DEVIATION                    -0.005411               0.028940
# TRANSIT_LEAD_TIME                           -0.006312              -0.064316
# PURCHASING_LEAD_TIME                        -0.009646              -0.121955
# DAYS_BETWEEN_ORDER_AND_DUE_DATE             -0.010721              -0.100627
# GIVEN_TIME_TO_LEAD_TIME_RATIO               -0.011823               0.094896
# DUE_DATE_WEEKDAY                            -0.018125              -0.059530
# PRODUCT_MARKET                               0.008129              -0.010569
# PRODUCT_STATUS                                    NaN                    NaN
# AVERAGE_DAILY_DEMAND_CASES                   0.000219               0.106836
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS              0.010207               0.013152
# AVERAGE_ORDER_CYCLE_DAYS                     0.010027              -0.041682
# AVERAGE_ORDER_CYCLE_CASES                    0.004952               0.072146
# LEAD_TIME_TO_DISTANCE_RATIO                 -0.030950              -0.103670
#
#                                        SHIP_FROM_VENDOR  ORDER_DAY_OF_WEEK  \
# ID                                            -0.001690           0.000034
# DIVISION_NUMBER                               -0.012856           0.028395
# PRODUCT_NUMBER                                -0.005264          -0.017917
# COMPANY_VENDOR_NUMBER                          0.730550          -0.072054
# SHIP_FROM_VENDOR                               1.000000          -0.039452
# ORDER_DAY_OF_WEEK                             -0.039452           1.000000
# PRODUCT_CLASSIFICATION                         0.092989          -0.021204
# PURCHASE_ORDER_TYPE                            0.078593          -0.056079
# DISTANCE_IN_MILES                             -0.131653          -0.008769
# PURCHASE_FROM_VENDOR                           0.126755          -0.076666
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET          0.063810          -0.029233
# ORDER_QUANTITY_DEVIATION                       0.012892          -0.026695
# TRANSIT_LEAD_TIME                              0.035595           0.030093
# PURCHASING_LEAD_TIME                           0.006878           0.074440
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                0.023651           0.048377
# GIVEN_TIME_TO_LEAD_TIME_RATIO                  0.083730          -0.110913
# DUE_DATE_WEEKDAY                              -0.055186           0.015239
# PRODUCT_MARKET                                 0.001140           0.007342
# PRODUCT_STATUS                                      NaN                NaN
# AVERAGE_DAILY_DEMAND_CASES                     0.037487          -0.046720
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                0.071044           0.014783
# AVERAGE_ORDER_CYCLE_DAYS                       0.048842          -0.000932
# AVERAGE_ORDER_CYCLE_CASES                      0.056108          -0.035974
# LEAD_TIME_TO_DISTANCE_RATIO                   -0.009378           0.103816
#
#                                        PRODUCT_CLASSIFICATION  \
# ID                                                   0.003754
# DIVISION_NUMBER                                     -0.061128
# PRODUCT_NUMBER                                       0.002122
# COMPANY_VENDOR_NUMBER                                0.328738
# SHIP_FROM_VENDOR                                     0.092989
# ORDER_DAY_OF_WEEK                                   -0.021204
# PRODUCT_CLASSIFICATION                               1.000000
# PURCHASE_ORDER_TYPE                                 -0.028969
# DISTANCE_IN_MILES                                   -0.088515
# PURCHASE_FROM_VENDOR                                 0.196703
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET               -0.173054
# ORDER_QUANTITY_DEVIATION                             0.013208
# TRANSIT_LEAD_TIME                                   -0.303764
# PURCHASING_LEAD_TIME                                -0.349758
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                     -0.331980
# GIVEN_TIME_TO_LEAD_TIME_RATIO                        0.093256
# DUE_DATE_WEEKDAY                                    -0.024993
# PRODUCT_MARKET                                      -0.002885
# PRODUCT_STATUS                                            NaN
# AVERAGE_DAILY_DEMAND_CASES                           0.019716
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                     -0.039269
# AVERAGE_ORDER_CYCLE_DAYS                            -0.095380
# AVERAGE_ORDER_CYCLE_CASES                           -0.058778
# LEAD_TIME_TO_DISTANCE_RATIO                         -0.076892
#
#                                        PURCHASE_ORDER_TYPE  DISTANCE_IN_MILES  \
# ID                                               -0.008048           0.009530
# DIVISION_NUMBER                                  -0.136128           0.028613
# PRODUCT_NUMBER                                   -0.012811           0.043117
# COMPANY_VENDOR_NUMBER                             0.093357          -0.086397
# SHIP_FROM_VENDOR                                  0.078593          -0.131653
# ORDER_DAY_OF_WEEK                                -0.056079          -0.008769
# PRODUCT_CLASSIFICATION                           -0.028969          -0.088515
# PURCHASE_ORDER_TYPE                               1.000000          -0.307324
# DISTANCE_IN_MILES                                -0.307324           1.000000
# PURCHASE_FROM_VENDOR                              0.019351          -0.104695
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET            -0.045753           0.115278
# ORDER_QUANTITY_DEVIATION                          0.017507          -0.015147
# TRANSIT_LEAD_TIME                                 0.219661           0.226557
# PURCHASING_LEAD_TIME                             -0.142805           0.310640
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                  -0.109811           0.281977
# GIVEN_TIME_TO_LEAD_TIME_RATIO                     0.249876          -0.216478
# DUE_DATE_WEEKDAY                                  0.044688          -0.076755
# PRODUCT_MARKET                                   -0.014760           0.013792
# PRODUCT_STATUS                                         NaN                NaN
# AVERAGE_DAILY_DEMAND_CASES                        0.002248           0.001668
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                  -0.084895           0.095138
# AVERAGE_ORDER_CYCLE_DAYS                         -0.064559           0.095437
# AVERAGE_ORDER_CYCLE_CASES                        -0.064350           0.046812
# LEAD_TIME_TO_DISTANCE_RATIO                      -0.007641          -0.335303
#
#                                        PURCHASE_FROM_VENDOR  ...  \
# ID                                                -0.004420  ...
# DIVISION_NUMBER                                   -0.092678  ...
# PRODUCT_NUMBER                                     0.010871  ...
# COMPANY_VENDOR_NUMBER                              0.390104  ...
# SHIP_FROM_VENDOR                                   0.126755  ...
# ORDER_DAY_OF_WEEK                                 -0.076666  ...
# PRODUCT_CLASSIFICATION                             0.196703  ...
# PURCHASE_ORDER_TYPE                                0.019351  ...
# DISTANCE_IN_MILES                                 -0.104695  ...
# PURCHASE_FROM_VENDOR                               1.000000  ...
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET             -0.040364  ...
# ORDER_QUANTITY_DEVIATION                           0.020624  ...
# TRANSIT_LEAD_TIME                                 -0.237484  ...
# PURCHASING_LEAD_TIME                              -0.282103  ...
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                   -0.271507  ...
# GIVEN_TIME_TO_LEAD_TIME_RATIO                      0.068555  ...
# DUE_DATE_WEEKDAY                                  -0.000958  ...
# PRODUCT_MARKET                                    -0.009170  ...
# PRODUCT_STATUS                                          NaN  ...
# AVERAGE_DAILY_DEMAND_CASES                         0.088537  ...
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                   -0.001613  ...
# AVERAGE_ORDER_CYCLE_DAYS                          -0.043280  ...
# AVERAGE_ORDER_CYCLE_CASES                          0.039716  ...
# LEAD_TIME_TO_DISTANCE_RATIO                       -0.054667  ...
#
#                                        DAYS_BETWEEN_ORDER_AND_DUE_DATE  \
# ID                                                           -0.003961
# DIVISION_NUMBER                                              -0.066182
# PRODUCT_NUMBER                                               -0.010721
# COMPANY_VENDOR_NUMBER                                        -0.100627
# SHIP_FROM_VENDOR                                              0.023651
# ORDER_DAY_OF_WEEK                                             0.048377
# PRODUCT_CLASSIFICATION                                       -0.331980
# PURCHASE_ORDER_TYPE                                          -0.109811
# DISTANCE_IN_MILES                                             0.281977
# PURCHASE_FROM_VENDOR                                         -0.271507
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET                         0.118822
# ORDER_QUANTITY_DEVIATION                                     -0.001871
# TRANSIT_LEAD_TIME                                             0.853955
# PURCHASING_LEAD_TIME                                          0.957562
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                               1.000000
# GIVEN_TIME_TO_LEAD_TIME_RATIO                                 0.061861
# DUE_DATE_WEEKDAY                                              0.075700
# PRODUCT_MARKET                                                0.011266
# PRODUCT_STATUS                                                     NaN
# AVERAGE_DAILY_DEMAND_CASES                                   -0.057039
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                               0.108532
# AVERAGE_ORDER_CYCLE_DAYS                                      0.120491
# AVERAGE_ORDER_CYCLE_CASES                                     0.029700
# LEAD_TIME_TO_DISTANCE_RATIO                                   0.071999
#
#                                        GIVEN_TIME_TO_LEAD_TIME_RATIO  \
# ID                                                          0.007843
# DIVISION_NUMBER                                            -0.037448
# PRODUCT_NUMBER                                             -0.011823
# COMPANY_VENDOR_NUMBER                                       0.094896
# SHIP_FROM_VENDOR                                            0.083730
# ORDER_DAY_OF_WEEK                                          -0.110913
# PRODUCT_CLASSIFICATION                                      0.093256
# PURCHASE_ORDER_TYPE                                         0.249876
# DISTANCE_IN_MILES                                          -0.216478
# PURCHASE_FROM_VENDOR                                        0.068555
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET                      -0.046123
# ORDER_QUANTITY_DEVIATION                                    0.002949
# TRANSIT_LEAD_TIME                                          -0.039709
# PURCHASING_LEAD_TIME                                       -0.141581
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                             0.061861
# GIVEN_TIME_TO_LEAD_TIME_RATIO                               1.000000
# DUE_DATE_WEEKDAY                                            0.017892
# PRODUCT_MARKET                                             -0.015660
# PRODUCT_STATUS                                                   NaN
# AVERAGE_DAILY_DEMAND_CASES                                  0.003285
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                            -0.034234
# AVERAGE_ORDER_CYCLE_DAYS                                   -0.043527
# AVERAGE_ORDER_CYCLE_CASES                                  -0.030143
# LEAD_TIME_TO_DISTANCE_RATIO                                -0.011144
#
#                                        DUE_DATE_WEEKDAY  PRODUCT_MARKET  \
# ID                                             0.004247       -0.002889
# DIVISION_NUMBER                                0.009276        0.014589
# PRODUCT_NUMBER                                -0.018125        0.008129
# COMPANY_VENDOR_NUMBER                         -0.059530       -0.010569
# SHIP_FROM_VENDOR                              -0.055186        0.001140
# ORDER_DAY_OF_WEEK                              0.015239        0.007342
# PRODUCT_CLASSIFICATION                        -0.024993       -0.002885
# PURCHASE_ORDER_TYPE                            0.044688       -0.014760
# DISTANCE_IN_MILES                             -0.076755        0.013792
# PURCHASE_FROM_VENDOR                          -0.000958       -0.009170
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET          0.008376        0.013495
# ORDER_QUANTITY_DEVIATION                       0.020194       -0.006140
# TRANSIT_LEAD_TIME                              0.088320        0.005854
# PURCHASING_LEAD_TIME                           0.080937        0.013428
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                0.075700        0.011266
# GIVEN_TIME_TO_LEAD_TIME_RATIO                  0.017892       -0.015660
# DUE_DATE_WEEKDAY                               1.000000       -0.030258
# PRODUCT_MARKET                                -0.030258        1.000000
# PRODUCT_STATUS                                      NaN             NaN
# AVERAGE_DAILY_DEMAND_CASES                     0.000825       -0.014562
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS               -0.059482        0.007942
# AVERAGE_ORDER_CYCLE_DAYS                      -0.057109        0.008805
# AVERAGE_ORDER_CYCLE_CASES                     -0.005982        0.006058
# LEAD_TIME_TO_DISTANCE_RATIO                    0.080825        0.002746
#
#                                        PRODUCT_STATUS  \
# ID                                                NaN
# DIVISION_NUMBER                                   NaN
# PRODUCT_NUMBER                                    NaN
# COMPANY_VENDOR_NUMBER                             NaN
# SHIP_FROM_VENDOR                                  NaN
# ORDER_DAY_OF_WEEK                                 NaN
# PRODUCT_CLASSIFICATION                            NaN
# PURCHASE_ORDER_TYPE                               NaN
# DISTANCE_IN_MILES                                 NaN
# PURCHASE_FROM_VENDOR                              NaN
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET             NaN
# ORDER_QUANTITY_DEVIATION                          NaN
# TRANSIT_LEAD_TIME                                 NaN
# PURCHASING_LEAD_TIME                              NaN
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                   NaN
# GIVEN_TIME_TO_LEAD_TIME_RATIO                     NaN
# DUE_DATE_WEEKDAY                                  NaN
# PRODUCT_MARKET                                    NaN
# PRODUCT_STATUS                                    NaN
# AVERAGE_DAILY_DEMAND_CASES                        NaN
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                   NaN
# AVERAGE_ORDER_CYCLE_DAYS                          NaN
# AVERAGE_ORDER_CYCLE_CASES                         NaN
# LEAD_TIME_TO_DISTANCE_RATIO                       NaN
#
#                                        AVERAGE_DAILY_DEMAND_CASES  \
# ID                                                      -0.006886
# DIVISION_NUMBER                                         -0.059713
# PRODUCT_NUMBER                                           0.000219
# COMPANY_VENDOR_NUMBER                                    0.106836
# SHIP_FROM_VENDOR                                         0.037487
# ORDER_DAY_OF_WEEK                                       -0.046720
# PRODUCT_CLASSIFICATION                                   0.019716
# PURCHASE_ORDER_TYPE                                      0.002248
# DISTANCE_IN_MILES                                        0.001668
# PURCHASE_FROM_VENDOR                                     0.088537
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET                    0.556759
# ORDER_QUANTITY_DEVIATION                                 0.004815
# TRANSIT_LEAD_TIME                                       -0.052586
# PURCHASING_LEAD_TIME                                    -0.049685
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                         -0.057039
# GIVEN_TIME_TO_LEAD_TIME_RATIO                            0.003285
# DUE_DATE_WEEKDAY                                         0.000825
# PRODUCT_MARKET                                          -0.014562
# PRODUCT_STATUS                                                NaN
# AVERAGE_DAILY_DEMAND_CASES                               1.000000
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                         -0.060615
# AVERAGE_ORDER_CYCLE_DAYS                                -0.108811
# AVERAGE_ORDER_CYCLE_CASES                                0.718063
# LEAD_TIME_TO_DISTANCE_RATIO                             -0.066837
#
#                                        AVERAGE_VENDOR_ORDER_CYCLE_DAYS  \
# ID                                                            0.004537
# DIVISION_NUMBER                                               0.084351
# PRODUCT_NUMBER                                                0.010207
# COMPANY_VENDOR_NUMBER                                         0.013152
# SHIP_FROM_VENDOR                                              0.071044
# ORDER_DAY_OF_WEEK                                             0.014783
# PRODUCT_CLASSIFICATION                                       -0.039269
# PURCHASE_ORDER_TYPE                                          -0.084895
# DISTANCE_IN_MILES                                             0.095138
# PURCHASE_FROM_VENDOR                                         -0.001613
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET                         0.102876
# ORDER_QUANTITY_DEVIATION                                     -0.008482
# TRANSIT_LEAD_TIME                                             0.043118
# PURCHASING_LEAD_TIME                                          0.112402
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                               0.108532
# GIVEN_TIME_TO_LEAD_TIME_RATIO                                -0.034234
# DUE_DATE_WEEKDAY                                             -0.059482
# PRODUCT_MARKET                                                0.007942
# PRODUCT_STATUS                                                     NaN
# AVERAGE_DAILY_DEMAND_CASES                                   -0.060615
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                               1.000000
# AVERAGE_ORDER_CYCLE_DAYS                                      0.843005
# AVERAGE_ORDER_CYCLE_CASES                                     0.238068
# LEAD_TIME_TO_DISTANCE_RATIO                                   0.002911
#
#                                        AVERAGE_ORDER_CYCLE_DAYS  \
# ID                                                    -0.006044
# DIVISION_NUMBER                                        0.082815
# PRODUCT_NUMBER                                         0.010027
# COMPANY_VENDOR_NUMBER                                 -0.041682
# SHIP_FROM_VENDOR                                       0.048842
# ORDER_DAY_OF_WEEK                                     -0.000932
# PRODUCT_CLASSIFICATION                                -0.095380
# PURCHASE_ORDER_TYPE                                   -0.064559
# DISTANCE_IN_MILES                                      0.095437
# PURCHASE_FROM_VENDOR                                  -0.043280
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET                  0.080980
# ORDER_QUANTITY_DEVIATION                              -0.011362
# TRANSIT_LEAD_TIME                                      0.062172
# PURCHASING_LEAD_TIME                                   0.126407
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                        0.120491
# GIVEN_TIME_TO_LEAD_TIME_RATIO                         -0.043527
# DUE_DATE_WEEKDAY                                      -0.057109
# PRODUCT_MARKET                                         0.008805
# PRODUCT_STATUS                                              NaN
# AVERAGE_DAILY_DEMAND_CASES                            -0.108811
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                        0.843005
# AVERAGE_ORDER_CYCLE_DAYS                               1.000000
# AVERAGE_ORDER_CYCLE_CASES                              0.178257
# LEAD_TIME_TO_DISTANCE_RATIO                            0.026879
#
#                                        AVERAGE_ORDER_CYCLE_CASES  \
# ID                                                     -0.001973
# DIVISION_NUMBER                                         0.015762
# PRODUCT_NUMBER                                          0.004952
# COMPANY_VENDOR_NUMBER                                   0.072146
# SHIP_FROM_VENDOR                                        0.056108
# ORDER_DAY_OF_WEEK                                      -0.035974
# PRODUCT_CLASSIFICATION                                 -0.058778
# PURCHASE_ORDER_TYPE                                    -0.064350
# DISTANCE_IN_MILES                                       0.046812
# PURCHASE_FROM_VENDOR                                    0.039716
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET                   0.745292
# ORDER_QUANTITY_DEVIATION                                0.005089
# TRANSIT_LEAD_TIME                                      -0.011954
# PURCHASING_LEAD_TIME                                    0.044032
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                         0.029700
# GIVEN_TIME_TO_LEAD_TIME_RATIO                          -0.030143
# DUE_DATE_WEEKDAY                                       -0.005982
# PRODUCT_MARKET                                          0.006058
# PRODUCT_STATUS                                               NaN
# AVERAGE_DAILY_DEMAND_CASES                              0.718063
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                         0.238068
# AVERAGE_ORDER_CYCLE_DAYS                                0.178257
# AVERAGE_ORDER_CYCLE_CASES                               1.000000
# LEAD_TIME_TO_DISTANCE_RATIO                            -0.030697
#
#                                        LEAD_TIME_TO_DISTANCE_RATIO
# ID                                                        0.002131
# DIVISION_NUMBER                                           0.119514
# PRODUCT_NUMBER                                           -0.030950
# COMPANY_VENDOR_NUMBER                                    -0.103670
# SHIP_FROM_VENDOR                                         -0.009378
# ORDER_DAY_OF_WEEK                                         0.103816
# PRODUCT_CLASSIFICATION                                   -0.076892
# PURCHASE_ORDER_TYPE                                      -0.007641
# DISTANCE_IN_MILES                                        -0.335303
# PURCHASE_FROM_VENDOR                                     -0.054667
# AVERAGE_PRODUCT_ORDER_QUANTITY_MARKET                    -0.000126
# ORDER_QUANTITY_DEVIATION                                  0.001769
# TRANSIT_LEAD_TIME                                         0.044198
# PURCHASING_LEAD_TIME                                      0.068295
# DAYS_BETWEEN_ORDER_AND_DUE_DATE                           0.071999
# GIVEN_TIME_TO_LEAD_TIME_RATIO                            -0.011144
# DUE_DATE_WEEKDAY                                          0.080825
# PRODUCT_MARKET                                            0.002746
# PRODUCT_STATUS                                                 NaN
# AVERAGE_DAILY_DEMAND_CASES                               -0.066837
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS                           0.002911
# AVERAGE_ORDER_CYCLE_DAYS                                  0.026879
# AVERAGE_ORDER_CYCLE_CASES                                -0.030697
# LEAD_TIME_TO_DISTANCE_RATIO                               1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# **Cleaning**

# %%
# Check for missing values
print(X_train.isna().sum().sort_values(ascending = False).head())
print(X_test.isna().sum().sort_values(ascending = False).head())
# Out:
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS    339
# AVERAGE_ORDER_CYCLE_DAYS           339
# AVERAGE_ORDER_CYCLE_CASES          339
# AVERAGE_DAILY_DEMAND_CASES          41
# COMPANY_VENDOR_NUMBER                0
# dtype: int64
# AVERAGE_VENDOR_ORDER_CYCLE_DAYS    184
# AVERAGE_ORDER_CYCLE_DAYS           184
# AVERAGE_ORDER_CYCLE_CASES          184
# AVERAGE_DAILY_DEMAND_CASES          13
# COMPANY_VENDOR_NUMBER                0
# dtype: int64

# %% [markdown]
# Four columns are missing data (for both the train and test datasets).

# %%
# Function to impute missing values for four columns (using median)
def clean_data(data):
    data['AVERAGE_VENDOR_ORDER_CYCLE_DAYS'] = data['AVERAGE_VENDOR_ORDER_CYCLE_DAYS'].fillna(data.AVERAGE_DAILY_DEMAND_CASES.median())
    data['AVERAGE_ORDER_CYCLE_DAYS'] = data['AVERAGE_ORDER_CYCLE_DAYS'].fillna(data.AVERAGE_DAILY_DEMAND_CASES.median())
    data['AVERAGE_ORDER_CYCLE_CASES'] = data['AVERAGE_ORDER_CYCLE_CASES'].fillna(data.AVERAGE_DAILY_DEMAND_CASES.median())
    data['AVERAGE_DAILY_DEMAND_CASES'] = data['AVERAGE_DAILY_DEMAND_CASES'].fillna(data.AVERAGE_DAILY_DEMAND_CASES.median())

# Apply to the datasets
clean_data(X_train)
clean_data(X_test)

# %%
# Function to remove columns
def remove(col):
    X_train.drop(col, axis = 1, inplace = True)
    X_test.drop(col, axis = 1, inplace = True)

# Apply on certain columns of no use
remove('ID')
remove('PURCHASE_ORDER_DUE_DATE')
remove('ORDER_DATE') # difference is same as 'DAYS_BETWEEN_ORDER_AND_DUE_DATE'
remove('RESERVABLE_INDICATOR') # only one value for all
remove('PRODUCT_STATUS') # only one value for all

# %% [markdown]
# **Categorical Data**

# %%
# Filter to ensure unique values are the same in train and test datasets
def filter_low_numbers(col, threshold):
    global X_train, X_test
    common_values = np.intersect1d(np.array(X_train_copy[col].value_counts().index), (np.array(X_test_copy[col].value_counts().index)))
    high_values = X_train_copy[col].value_counts()[X_train_copy[col].value_counts() > threshold].index
    good_values = np.intersect1d(common_values, high_values)
    X_train[col] = X_train[col].apply(lambda x: x if x in good_values else 'OTHER')
    X_test[col] = X_test[col].apply(lambda x: x if x in good_values else 'OTHER')

# Apply on categorical columns
filter_low_numbers('DIVISION_NUMBER', 1)
filter_low_numbers('PRODUCT_NUMBER', 1)
filter_low_numbers('COMPANY_VENDOR_NUMBER', 1)
filter_low_numbers('SHIP_FROM_VENDOR', 1)
filter_low_numbers('ORDER_DAY_OF_WEEK', 1)
filter_low_numbers('PRODUCT_CLASSIFICATION', 1)
filter_low_numbers('PURCHASE_ORDER_TYPE', 1)
filter_low_numbers('DIVISION_CODE', 1)
filter_low_numbers('DUE_DATE_WEEKDAY', 1)
filter_low_numbers('PRODUCT_MARKET', 0)

# %%
# Get dummies on categorical data
X_train_dummy = pd.get_dummies(X_train, drop_first = True)
X_test_dummy = pd.get_dummies(X_test, drop_first = True)

# %% [markdown]
# **Check**

# %%
X_train_dummy.shape
# Out:
# (20413, 6402)

# %%
X_test_dummy.shape
# Out:
# (10247, 6402)

# %% [markdown]
# The train and test datasets have the same number of columns; good to move on.

# %% [markdown]
# **Model**

# %%
# Find the best predictors
selector = SelectKBest(k = 100)
X_selected_train = selector.fit_transform(X_train_dummy, y_train['ON_TIME_AND_COMPLETE'])
X_selected_test = selector.transform(X_test_dummy)

# See predictors
#features = selector.get_feature_names_out()
#print(features)

# %%
# Polynomial Features
poly = PolynomialFeatures(2, include_bias = False)
X_train_poly = poly.fit_transform(X_selected_train)
X_test_poly = poly.transform(X_selected_test)

# %%
X_train_poly.shape
# Out:
# (20413, 5150)

# %%
# Scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_poly)
X_test_scaled = scaler.transform(X_test_poly)

# %%
# Separate train and test
#X_train_validate, X_test_validate, y_train_validate, y_test_validate = train_test_split(pd.DataFrame(X_train_scaled), y_train['ON_TIME_AND_COMPLETE'], stratify = y_train['ON_TIME_AND_COMPLETE'],test_size = 0.25, random_state = 3)

# %%
# Create model
model = LogisticRegression(solver = 'saga', penalty = 'l1', C = 1, n_jobs = -1)
model.fit(X_train_scaled, y_train['ON_TIME_AND_COMPLETE'])
# Out:
# /Users/gracefan/anaconda3/envs/stat303_conda_env/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(C=1, n_jobs=-1, penalty='l1', solver='saga')

# %%
# Look at train validate metrics
probabilities = model.predict_proba(X_train_scaled)[:,1]
predictions = (probabilities >= 0.5).astype(int)
print('Accuracy: ', accuracy_score(y_train['ON_TIME_AND_COMPLETE'], predictions))
print('Precision: ', precision_score(y_train['ON_TIME_AND_COMPLETE'], predictions))
print('Recall: ', recall_score(y_train['ON_TIME_AND_COMPLETE'], predictions))
print('F1: ', f1_score(y_train['ON_TIME_AND_COMPLETE'], predictions))
# Out:
# Accuracy:  0.8102679664919414
# Precision:  0.8246490854955338
# Recall:  0.7771319771520192
# F1:  0.8001857297631946

# %%
# Look at the predictions
predictions
# Out:
# array([1, 0, 0, ..., 1, 0, 0])

# %% [markdown]
# **CSV File**

# %%
# Prepare the dataset
probabilities = model.predict_proba(X_test_scaled)[:,1]
predictions = (probabilities >= 0.5).astype(int)
X_test2 = pd.read_csv('../Datasets/public_private_X.csv')
X_test2['ON_TIME_AND_IS_COMPLETE'] = predictions
final = X_test2[['ID', 'ON_TIME_AND_IS_COMPLETE']]
display(final.tail())
display(final.shape)
# Out:
#           ID  ON_TIME_AND_IS_COMPLETE
# 10242  30641                        1
# 10243  30642                        1
# 10244  30654                        1
# 10245  30657                        0
# 10246  30659                        1
# (10247, 2)

# %%
# Create the CSV file
#final.to_csv('Predictions12.csv', index = False)

# %%
# Check the file
#predictions_csv = pd.read_csv('Predictions12.csv')
#display(predictions_csv.tail())
#print(predictions_csv.shape)
